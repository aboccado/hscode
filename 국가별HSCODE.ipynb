# %%
import pandas as pd

# %%
df = pd.read_excel('2022년_EU_관세율표.xlsx',dtype = str)

# %%
# 예를 들어, 유럽연합(EU)이 특정 국가들과 무역 협정을 맺었다면, 이 협정에 포함되지 않은 "모든 기타 국가들(All Third Countries)"에 대해서는 다른 관세율이 적용될 수 있습니다. 이는 무역 협정에 참여하는 국가들에게는 특정 혜택을 제공하고, 그 외의 국가들에게는 일반적인 관세율을 적용하기 위함입니다.

# %%
df.head(10)
# Out:
#    순번    년도 국가코드          세번                                   영문품명  \
# 0   1  2022  EEC        0101  Live horses, asses, mules and hinnies
# 1   2  2022  EEC         NaN                               - Horses
# 2   3  2022  EEC  0101210000         - - Pure-bred breeding animals
# 3   4  2022  EEC      010129                              - - Other
# 4   5  2022  EEC  0101291000                    - - - For slaughter
# 5   6  2022  EEC  0101299000                            - - - Other
# 6   7  2022  EEC  0101300000                                - Asses
# 7   8  2022  EEC  0101900000                                - Other
# 8   9  2022  EEC        0102                    Live bovine animals
# 9  10  2022  EEC         NaN                               - Cattle
#
#                 한글품명    단위                                       한국협정세율  \
# 0  살아 있는 말ㆍ당나귀ㆍ노새ㆍ버새   NaN                                          NaN
# 1                - 말   NaN                                          NaN
# ...

# %%
df['세번'].nunique()
# Out:
# 21955
